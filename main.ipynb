# %%
# !pip install -r requirements.txt
from warpdrive import WarpDrive


wd = WarpDrive()

min = wd.get_args("min")
max = wd.get_args("max")
# your code here

print("✅ Python is working!")

# Simple math test
a, b = 5, 7
print("Sum:", a + b)

# Loop test
for i in range(3):
    print("Count:", i)
